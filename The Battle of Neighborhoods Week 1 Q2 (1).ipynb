# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods #
# ### _Kitchener Vs. Waterloo, ON_ ###
# ##### Can a New Sushi Restauraunt be Sucessful in Either Kitchener or Waterloo Neighbourhoods? #####

# %% [markdown]
# <img src="https://i.pinimg.com/originals/65/50/cb/6550cb609b6ad9ca31a7795d2b0d786c.jpg" width="400" height="400"/>

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# * Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.

# %% [markdown]
# In this project we will try to find an optimal location for stakeholders to open a new sushi restaurant in either **Kitchener** or **Waterloo**, ON.
#
# Sushi is a popular choice in the area of Kitchener and Waterloo. This is partly due to the Universities in town and the booming tech scene that supply patrons of these restauraunts. Sushi in the area of Kitchener and Waterloo can be a quick, easy meal and it can also be a tidy meal because it offers many delicious bite size varieties. (No one likes to go back to the office with burger sauce, or salsa on their shirt for example). It's a convenient option that many people enjoy and can be a fun new experiecne for many patrons. It can also provide a very intimate setting throught the idea of food sharing so it is also a versitile setting that can range from romantic date, to family outing, to business meeting.
#
# With so many options of attracting different kinds of patrons with different needs and due to it's popularity in the Kitchener/ Waterloo area it seems natural that stakeholdrs could be interested in investing in a new sushi restauraunt in the area. However, is this type of restauraunt already too puplular in the area? Is there any space left in these neighbourhoods where a new restauraunt could be sucessful?
#
# To answer these questions we will need to find out if these areas are already too saturated to support another sushi restauraunt. Since there is assumed to be a lot of sushi resatauraunts in the Kitchener/Waterloo area we will try to detect **locations that are not already crowded with sushi restaurants**. We are interested in **areas with little or no sushi restaurants in these neighbourhoods**. We would also prefre locations **as close to the Universities as possible**, assuming that the first two conditions are met.
#
# We will use data analysis to generate a few of the most promising areas of Kitchener/Waterloo neighbourhoods for a new sushi restauraunt based on this criteria so that a final location can be chosen by stakeholders or so that we can determine that this type of restauraunt is not likely to be sucessful in these areas and perhaps determine that the stakeholders should continue their search in another nearby area such as Cambridge or Elmira,ON. Or, perhaps the data will show that they should look at choosing a different type of restauraunt altogether if they are set on entering the market in these neighbourhoods.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * number of and distance to sushi restaurants in the neighborhood, if any
# * distance of neighborhood from any Universities (or if no Universities available in the area then Colleges)
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
# * centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
# * number of restaurants and their type and location in every neighborhood will be obtained using **Foursquare API**
# * coordinate of Kitchener/Waterloo center will be obtained using **Google Maps API geocoding** of their respective Universities/Colleges

# %% [markdown]
# ### Neighborhood Candidates
#
# First we will install our required modules and import any necessary libraries to be able to execute our data requirements.

# %%
#Installing shapely module
# !pip install shapely
# Out:
# Requirement already satisfied: shapely in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.7.1)

# %%
#Installing folium module
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
#Installing pyproj module
# !pip install pyproj
# Out:
# Requirement already satisfied: pyproj in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (3.0.0.post1)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pyproj) (2020.12.5)

# %%
#Import libraries
import requests
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import folium
import math
import shapely.geometry
import pyproj
import warnings
warnings.filterwarnings('ignore')

from pandas.io.json import json_normalize

# %% [markdown]
# Then, we will create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest which is aprox. 4x4 killometers centered around Kitchener and Waterloo Universities/Colleges.
#
# Let's first find the latitude & longitude of Kitchener and Waterloo's Universities/Colleges, using specific, well known address and Google Maps geocoding API.

# %%
api_key =  'SECRET'

# %%
#Co-rodinates of University of Waterloo
def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
    
address = 'University of Waterloo 200 University Ave W, Waterloo, ON N2L 3G1'
Waterloo = get_coordinates(api_key, address)
print('Coordinate of {}: {}'.format(address, Waterloo))
# Out:
# Coordinate of University of Waterloo 200 University Ave W, Waterloo, ON N2L 3G1: [43.47129950000001, -80.542715]

# %%
#Co-rodinates of Kitchener's Conestoga College
def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address2)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
    
address2 = 'Conestoga College 299 Doon Valley Dr, Kitchener, ON N2G 4M4'
Kitchener = get_coordinates(api_key, address2)
print('Coordinate of {}: {}'.format(address2, Kitchener))
# Out:
# Coordinate of Conestoga College 299 Doon Valley Dr, Kitchener, ON N2G 4M4: [43.3895633, -80.4051748]

# %% [markdown]
# Now let's create a grid of area candidates, equaly spaced, centered around the University/College areas. Our neighborhoods will be defined as circular areas with a radius of 300 meters, so our neighborhood centers will be 600 meters apart.
#
# To accurately calculate distances we need to create our grid of locations in Cartesian 2D coordinate system which allows us to calculate distances in meters (not in latitude/longitude degrees). Then we'll project those coordinates back to latitude/longitude degrees to be shown on Folium map. So let's create functions to convert between WGS84 spherical coordinate system (latitude/longitude degrees) and UTM Cartesian coordinate system (X/Y coordinates in  meters).

# %%
#Waterloo
def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('Waterloo Center longitude={}, latitude={}'.format(Waterloo[1], Waterloo[0]))
x, y = lonlat_to_xy(Waterloo[1], Waterloo[0])
print('Waterloo Center UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Waterloo Center longitude={}, latitude={}'.format(lo, la))
# Out:
# Coordinate transformation check
# -------------------------------
# Waterloo Center longitude=-80.542715, latitude=43.47129950000001
# Waterloo Center UTM X=-5322667.908010452, Y=10645104.040561661
# Waterloo Center longitude=-80.54271500000054, latitude=43.471299499999866

# %%
#Kitchener
def lonlat_to_xy2(lon2, lat2):
    proj_latlon2 = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy2 = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy2 = pyproj.transform(proj_latlon2, proj_xy2, lon2, lat2)
    return xy2[0], xy2[1]

def xy_to_lonlat2(x2, y2):
    proj_latlon2 = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy2 = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat2 = pyproj.transform(proj_xy2, proj_latlon2, x2, y2)
    return lonlat2[0], lonlat2[1]

def calc_xy_distance2(x1, y1, x2, y2):
    dx2 = x2 - x1
    dy2 = y2 - y1
    return math.sqrt(dx2*dx2 + dy2*dy2)

print('Coordinate transformation check')
print('-------------------------------')
print('Kitchener Center longitude={}, latitude={}'.format(Kitchener[1], Kitchener[0]))
x2, y2 = lonlat_to_xy2(Kitchener[1], Kitchener[0])
print('Kitchener Center UTM X={}, Y={}'.format(x2, y2))
lo2, la2 = xy_to_lonlat2(x2, y2)
print('Kitchener Center longitude={}, latitude={}'.format(lo2, la2))
# Out:
# Coordinate transformation check
# -------------------------------
# Kitchener Center longitude=-80.4051748, latitude=43.3895633
# Kitchener Center UTM X=-5337868.099955836, Y=10630979.133620983
# Kitchener Center longitude=-80.40517480000055, latitude=43.38956329999985

# %% [markdown]
# Let's create a **hexagonal grid of cells**: we offset every other row, and adjust vertical row spacing so that **every cell center is equally distant from all it's neighbors**.

# %%
#Waterloo
waterloo_center_x, waterloo_center_y = lonlat_to_xy(Waterloo[1], Waterloo[0]) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = waterloo_center_x - 6000
x_step = 600
y_min = waterloo_center_y - 6000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(waterloo_center_x, waterloo_center_y, x, y)
        if (distance_from_center <= 4000):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 162 candidate neighborhood centers generated.

# %%
#Kitchener
kitchener_center_x, kitchener_center_y = lonlat_to_xy2(Kitchener[1], Kitchener[0]) # City center in Cartesian coordinates

k2 = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min2 = kitchener_center_x - 6000
x_step2 = 600
y_min2 = kitchener_center_y - 6000 - (int(21/k2)*k2*600 - 12000)/2
y_step2 = 600 * k2 

latitudes2 = []
longitudes2 = []
distances_from_center2 = []
xs2 = []
ys2 = []
for i2 in range(0, int(21/k2)):
    y2 = y_min2 + i2 * y_step2
    x_offset2 = 300 if i2%2==0 else 0
    for j2 in range(0, 21):
        x2 = x_min2 + j2 * x_step2 + x_offset2
        distance_from_center2 = calc_xy_distance2(kitchener_center_x, kitchener_center_y, x2, y2)
        if (distance_from_center2 <= 4000):
            lon2, lat2 = xy_to_lonlat2(x2, y2)
            latitudes2.append(lat2)
            longitudes2.append(lon2)
            distances_from_center2.append(distance_from_center2)
            xs2.append(x2)
            ys2.append(y2)

print(len(latitudes2), 'candidate neighborhood centers generated.')
# Out:
# 162 candidate neighborhood centers generated.

# %%
map_combined = folium.Map(location=Waterloo and Kitchener, zoom_start=12)
folium.Marker(Waterloo, popup='Waterloo - Univerisy Of Waterloo').add_to(map_combined)
folium.Marker(Kitchener, popup='Kitchener - Conestoga College').add_to(map_combined)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_combined) 
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_combined)
for lat2, lon2 in zip(latitudes2, longitudes2):
      #folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_combined) 
    folium.Circle([lat2, lon2], radius=300, color='red', fill=False).add_to(map_combined)
map_combined
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cd46971316444e2fbafc43d17a5682c4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cd46971316444e2fbafc43d17a5682c4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cd46971316444e2fbafc43d17a5682c4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_cd46971316444e2fbafc43d17a5682c4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.3895633%2C%20-80.4051748%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# OK, we now have the coordinates of centers of neighborhoods/areas to be evaluated, equally spaced (distance from every point to it's neighbors is exactly the same) and within ~4km from it's University/College.
#
# Let's now use Google Maps API to get approximate addresses of those locations.

# %%
#Waterloo
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(api_key, Waterloo[0], Waterloo[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(Waterloo[0], Waterloo[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [43.47129950000001, -80.542715] is: Earth Sciences and Chemistry, University of, 200 University Ave W, Waterloo, ON N2L 3G1, Canada

# %%
#Kitchener
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(api_key, Kitchener[0], Kitchener[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(Kitchener[0], Kitchener[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [43.3895633, -80.4051748] is: 299 Doon Valley Dr, Kitchener, ON N2G 4M4, Canada

# %%
#Waterloo
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Canada', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')

print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
#Kitchener
print('Obtaining location addresses: ', end='')
addresses2 = []
for lat2, lon2 in zip(latitudes2, longitudes2):
    address2 = get_address(api_key, lat2, lon2)
    if address is None:
        address2 = 'NO ADDRESS'
    address2 = address2.replace(', Canada', '') # We don't need country part of address
    addresses2.append(address2)
    print(' .', end='')

print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
#Waterloo
addresses[10:30]
# Out:
# ['University Ave. / Conestoga College - Waterloo, Waterloo, ON N2J 2W2',
#  '332 Marsland Dr, Waterloo, ON N2J 3Z1',
#  '200 Dearborn Blvd, Waterloo, ON N2J 4Y3',
#  '130 Mt Hope St, Kitchener, ON N2G 4M6',
#  '11 John St W, Waterloo, ON N2L 1A6',
#  '43 George St, Waterloo, ON N2J 1K6',
#  '7 Peppler St, Waterloo, ON N2J 3C2',
#  '82 Peppler St, Waterloo, ON N2J 3C8',
#  '61 Marshall St, Waterloo, ON N2J 2T3',
#  '65 University Ave E, Waterloo, ON N2J 2V9',
#  '315 Waterloo Regional Rd 8, Waterloo, ON N2J 3H8',
#  '400 Weber St N, Waterloo, ON N2J 3J3',
#  '50 Blue Springs Dr, Waterloo, ON N2J 4M4',
#  '362 Tealby Pl, Waterloo, ON N2J 0A1',
#  '94 Claremont Ave, Kitchener, ON N2M 2P6',
#  '157 Belmont Ave, Waterloo, ON N2L 2B2',
#  '40 Fullerton St, Waterloo, ON N2L 6L4',
#  '50-75 King St S, Waterloo, ON N2J 1P2',
#  '15 Bridgeport Rd W, Waterloo, ON N2L 2X9',
#  '151 King St N, Waterloo, ON N2J 2Y1']

# %%
#Kitchener
addresses2[10:30]
# Out:
# ['365 Linden Dr, Cambridge, ON N3H 5L5',
#  'ON-401, Kitchener, ON N2P',
#  '4610 King St E, Kitchener, ON N2P 2G6',
#  '1182 Langdon Dr, Cambridge, ON N1R 5S3',
#  '46 Fallbrook Ln, Cambridge, ON N3H 4R8',
#  '24 Fallbrook Ln, Cambridge, ON N3H 4R8',
#  '1580 Blair Rd, Ayr, ON N0B 1E0',
#  'Fountain St S, Cambridge, ON N3H 1J2',
#  '740 Linden Dr, Cambridge, ON N3H 5L5',
#  '570 Linden Dr, Cambridge, ON N3H 0C9',
#  '45 Greensview Dr, Kitchener, ON N2P 2E6',
#  '48 Limerick Dr, Kitchener, ON N2P 2H1',
#  '150 Gateway Park Dr, Kitchener, ON N2P 2J4',
#  '100 Gateway Park Dr, Kitchener, ON N2P 2J4',
#  '1536 1 Township Rd, Cambridge, ON N1R 5S3',
#  '81 John Bricker Rd, Cambridge, ON N3H 4R8',
#  '75 John Bricker Rd, Cambridge, ON N3H 4R8',
#  '12 Ashton St, Cambridge, ON N3H 4R8',
#  '1740 Blair Rd, Cambridge, ON N3H 4R8',
#  '780 Fountain St S, Cambridge, ON N3H 1J2']

# %%
#Waterloo Dataframe
df_locations =pd.DataFrame({'Address': addresses,
                           'Latitude': latitudes,
                           'Longitude': longitudes,
                           'X':xs,
                           'Y':ys,
                           'Distance From Center': distances_from_center})
df_locations.tail(20)
# Out:
#                                               Address   Latitude  Longitude  \
# 142   1211 Fischer-Hallman Rd N, Waterloo, ON N2T 2P5  43.465333 -80.564034
# 143  Columbia / Fischer-Hallman, Waterloo, ON N2L 5M1  43.469040 -80.564752
# 144                262 Residence Rd, Waterloo, ON N2L  43.472746 -80.565470
# 145                   Laurelwood Dr, Waterloo, ON N2L  43.476453 -80.566188
# 146                581 Bearinger Rd, Waterloo, ON N2L  43.480160 -80.566907
# 147                359 Bearinger Rd, Waterloo, ON N2L  43.483867 -80.567625
# 148             390 Lakeview Dr, Waterloo, ON N2L 4Z6  43.487575 -80.568343
# 149    109 Frederick Banting Pl, Waterloo, ON N2T 1C4  43.455616 -80.566645
# 150            503 Ennismore Pl, Waterloo, ON N2T 2G3  43.459322 -80.567363
# 151           516 Queensdale Ct, Waterloo, ON N2T 1P7  43.463028 -80.568082
# 152         450 Columbia St. W., Waterloo, ON N2T 2N3  43.466734 -80.568800
# 153    426 Timbercroft Crescent, Waterloo, ON N2T 2J1  43.470440 -80.569518
# 154    500 Fischer-Hallman Rd N, Waterloo, ON N2L 0B1  43.474147 -80.570237
# 155           250 Laurelwood Dr, Waterloo, ON N2V 2R4  43.477853 -80.570956
# 156                Unnamed Road, Waterloo, ON N2J 3Z4  43.481560 -80.571675
# 157             588 Wingrove Ct, Waterloo, ON N2T 2C2  43.460721 -80.572128
# 158        539 Clair Creek Blvd, Waterloo, ON N2T 1R9  43.464427 -80.572847
# 159           525 Cairncroft Pl, Waterloo, ON N2T 2J5  43.468133 -80.573566
# 160             257 Pineland Pl, Waterloo, ON N2T 2S4  43.471840 -80.574285
# 161           290 Laurelwood Dr, Waterloo, ON N2J 3Z4  43.475546 -80.575005
#
#                 X             Y  Distance From Center
# 142 -5.323268e+06  1.064770e+07           2666.458325
# 143 -5.322668e+06  1.064770e+07           2598.076211
# 144 -5.322068e+06  1.064770e+07           2666.458325
# 145 -5.321468e+06  1.064770e+07           2861.817604
# 146 -5.320868e+06  1.064770e+07           3160.696126
# 147 -5.320268e+06  1.064770e+07           3536.947837
# 148 -5.319668e+06  1.064770e+07           3968.626967
# 149 -5.324768e+06  1.064822e+07           3758.989226
# 150 -5.324168e+06  1.064822e+07           3459.768778
# 151 -5.323568e+06  1.064822e+07           3244.996148
# 152 -5.322968e+06  1.064822e+07           3132.091953
# 153 -5.322368e+06  1.064822e+07           3132.091953
# 154 -5.321768e+06  1.064822e+07           3244.996148
# 155 -5.321168e+06  1.064822e+07           3459.768778
# 156 -5.320568e+06  1.064822e+07           3758.989226
# 157 -5.323868e+06  1.064874e+07           3830.143600
# 158 -5.323268e+06  1.064874e+07           3686.461718
# 159 -5.322668e+06  1.064874e+07           3637.306696
# 160 -5.322068e+06  1.064874e+07           3686.461718
# 161 -5.321468e+06  1.064874e+07           3830.143600

# %%
#Kitchener Dataframe
df_locations2 =pd.DataFrame({'Address': addresses2,
                           'Latitude': latitudes2,
                           'Longitude': longitudes2,
                           'X':xs2,
                           'Y':ys2,
                           'Distance From Center': distance_from_center2})
df_locations2.tail(20)
# Out:
#                                                Address   Latitude  Longitude  \
# 142               213 Doon S Dr, Kitchener, ON N2P 2L8  43.383658 -80.426455
# 143              40 Mitierra Dr, Kitchener, ON N2P 1C8  43.387359 -80.427155
# 144  Old Carriage / Homer Watson, Kitchener, ON N2P...  43.391061 -80.427854
# 145             56 Arrowhead Pl, Kitchener, ON N2P 1C3  43.394763 -80.428553
# 146          35 Green Valley Dr, Kitchener, ON N2P 2A5  43.398466 -80.429253
# 147             44 Mill Park Dr, Kitchener, ON N2P 1H4  43.402168 -80.429953
# 148             200 Wabanaki Dr, Kitchener, ON N2C 2E8  43.405871 -80.430653
# 149          55 George Ayres Dr, Kitchener, ON N2P 0G5  43.373963 -80.429102
# 150   568 Topper Woods Crescent, Kitchener, ON N2P 2Y3  43.377664 -80.429801
# 151               360 Doon S Dr, Kitchener, ON N2P 2T6  43.381365 -80.430501
# 152           51 Pine Valley Dr, Kitchener, ON N2P 2V9  43.385067 -80.431200
# 153        1115 Doon Village Rd, Kitchener, ON N2P 1A6  43.388768 -80.431900
# 154          71 Old Carriage Dr, Kitchener, ON N2P 1H5  43.392470 -80.432600
# 155               40 Pioneer Dr, Kitchener, ON N2P 2A4  43.396173 -80.433300
# 156          30 Green Valley Dr, Kitchener, ON N2P 1G8  43.399875 -80.434001
# 157        557 Robert Ferrie Dr, Kitchener, ON N2P 2T8  43.379072 -80.434545
# 158          219 Pine Valley Dr, Kitchener, ON N2P 2V8  43.382774 -80.435245
# 159               10 Oakdale Ct, Kitchener, ON N2P 2S9  43.386475 -80.435946
# 160            40 St Emilion Pl, Kitchener, ON N2P 1X2  43.390177 -80.436646
# 161           Pioneer / Bechtel, Kitchener, ON N2P 2C2  43.393879 -80.437347
#
#                 X             Y  Distance From Center
# 142 -5.338468e+06  1.063358e+07            8286.73639
# 143 -5.337868e+06  1.063358e+07            8286.73639
# 144 -5.337268e+06  1.063358e+07            8286.73639
# 145 -5.336668e+06  1.063358e+07            8286.73639
# 146 -5.336068e+06  1.063358e+07            8286.73639
# 147 -5.335468e+06  1.063358e+07            8286.73639
# 148 -5.334868e+06  1.063358e+07            8286.73639
# 149 -5.339968e+06  1.063410e+07            8286.73639
# 150 -5.339368e+06  1.063410e+07            8286.73639
# 151 -5.338768e+06  1.063410e+07            8286.73639
# 152 -5.338168e+06  1.063410e+07            8286.73639
# 153 -5.337568e+06  1.063410e+07            8286.73639
# 154 -5.336968e+06  1.063410e+07            8286.73639
# 155 -5.336368e+06  1.063410e+07            8286.73639
# 156 -5.335768e+06  1.063410e+07            8286.73639
# 157 -5.339068e+06  1.063462e+07            8286.73639
# 158 -5.338468e+06  1.063462e+07            8286.73639
# 159 -5.337868e+06  1.063462e+07            8286.73639
# 160 -5.337268e+06  1.063462e+07            8286.73639
# 161 -5.336668e+06  1.063462e+07            8286.73639

# %%
#Merging the Waterloo and Kitchener Dataframes into one Dataframe
df3 = df_locations.append(df_locations2)

# %%
#Checking to ensure dataframe merged sucessfully
df3.head(20)
# Out:
#                                               Address   Latitude  Longitude  \
# 0                165 Allen St E, Waterloo, ON N2J 1J7  43.467034 -80.510437
# 1    125 Waterloo Regional Rd 9, Waterloo, ON N2J 2K3  43.470741 -80.511148
# 2   Moses Springer Community Centre, 150 Lincoln R...  43.474448 -80.511859
# 3            219 Dixie Crescent, Waterloo, ON N2J 3K9  43.478155 -80.512570
# 4              20 Northcrest Pl, Waterloo, ON N2J 3X4  43.481863 -80.513282
# 5                 55 Union St E, Waterloo, ON N2J 1B9  43.461026 -80.513777
# 6                124 Allen St E, Waterloo, ON N2J 1J4  43.464733 -80.514488
# 7            75 Bridgeport Rd E, Waterloo, ON N2J 2K1  43.468439 -80.515200
# 8             99 Elgin Crescent, Waterloo, ON N2J 2S3  43.472146 -80.515911
# 9               182b Weber St N, Waterloo, ON N2J 3H4  43.475853 -80.516623
# 10  University Ave. / Conestoga College - Waterloo...  43.479560 -80.517335
# 11              332 Marsland Dr, Waterloo, ON N2J 3Z1  43.483268 -80.518047
# 12            200 Dearborn Blvd, Waterloo, ON N2J 4Y3  43.486975 -80.518759
# 13              130 Mt Hope St, Kitchener, ON N2G 4M6  43.455018 -80.517115
# 14                 11 John St W, Waterloo, ON N2L 1A6  43.458724 -80.517827
# 15                 43 George St, Waterloo, ON N2J 1K6  43.462430 -80.518539
# 16                 7 Peppler St, Waterloo, ON N2J 3C2  43.466137 -80.519251
# 17                82 Peppler St, Waterloo, ON N2J 3C8  43.469843 -80.519963
# 18               61 Marshall St, Waterloo, ON N2J 2T3  43.473550 -80.520675
# 19          65 University Ave E, Waterloo, ON N2J 2V9  43.477257 -80.521388
#
#                X             Y  Distance From Center
# 0  -5.323868e+06  1.064147e+07           3830.143600
# 1  -5.323268e+06  1.064147e+07           3686.461718
# 2  -5.322668e+06  1.064147e+07           3637.306696
# 3  -5.322068e+06  1.064147e+07           3686.461718
# 4  -5.321468e+06  1.064147e+07           3830.143600
# 5  -5.324768e+06  1.064199e+07           3758.989226
# 6  -5.324168e+06  1.064199e+07           3459.768778
# 7  -5.323568e+06  1.064199e+07           3244.996148
# 8  -5.322968e+06  1.064199e+07           3132.091953
# 9  -5.322368e+06  1.064199e+07           3132.091953
# 10 -5.321768e+06  1.064199e+07           3244.996148
# 11 -5.321168e+06  1.064199e+07           3459.768778
# 12 -5.320568e+06  1.064199e+07           3758.989226
# 13 -5.325668e+06  1.064251e+07           3968.626967
# 14 -5.325068e+06  1.064251e+07           3536.947837
# 15 -5.324468e+06  1.064251e+07           3160.696126
# 16 -5.323868e+06  1.064251e+07           2861.817604
# 17 -5.323268e+06  1.064251e+07           2666.458325
# 18 -5.322668e+06  1.064251e+07           2598.076211
# 19 -5.322068e+06  1.064251e+07           2666.458325

# %%
#checking to see if the merging of the dataframes worked
print('Number of colums in Dataframe : ', len(df_locations.columns))
print('Number of rows in Dataframe : ', len(df_locations.index))
print('Number of colums in Dataframe : ', len(df3.columns))
print('Number of rows in Dataframe : ', len(df3.index))
# Out:
# Number of colums in Dataframe :  6
# Number of rows in Dataframe :  162
# Number of colums in Dataframe :  6
# Number of rows in Dataframe :  324

# %% [markdown]
# ### Foursquare
# Now that we have our location candidates, we will use Foursquare API to get info on restaurants in each neighborhood.
#
# We're interested in venues in 'food' category, but only those that are proper restaurants - coffe shops, pizza places, bakeries etc. are not direct competitors so we don't care about those. So we will include in our list only venues that have 'restaurant' in category name, and we'll make sure to detect and include all the subcategories of specific 'sushi restaurant' category, as we need info on sushi restaurants in the neighborhood.

# %% [markdown]
# Foursquare credentials are defined in cell bellow.

# %%
# Define Foursquare Credentials
CLIENT_ID = 'SECRET' # your Foursquare ID
CLIENT_SECRET = 'SECRET' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SECRET
# CLIENT_SECRET:SECRET

# %%
#Finding Sushi Restauraunts Near Unitversity of Waterloo In Waterloo
search_query ='sushi'
radius = 5000 #(5km)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Waterloo[0], Waterloo[1], VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SECRET&client_secret=SECRET&ll=43.47129950000001,-80.542715&v=20180604&query=sushi&radius=5000&limit=30'

# %%
#Finding Sushi Restauraunts Near Conestoga College In Kitchener
search_query2 ='sushi'
radius2 = 5000 #(5km)

url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Kitchener[0], Kitchener[1], VERSION, search_query2, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SECRET&client_secret=SECRET&ll=43.3895633,-80.4051748&v=20180604&query=sushi&radius=5000&limit=30'

# %%
#Finding All Restauraunts In Waterloo
search_query3 ='Restaurant'
radius3 = 100000 #(100km)
LIMIT3 = 100

url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Waterloo[0], Waterloo[1], VERSION, search_query3, radius, LIMIT3)
url3
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SECRET&client_secret=SECRET&ll=43.47129950000001,-80.542715&v=20180604&query=Restaurant&radius=5000&limit=100'

# %%
#Finding All Restauraunts In Kitchener
search_query4 ='Restaurant'
radius4 = 100000 #(100km)
LIMIT4 = 100

url4 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, Kitchener[0], Kitchener[1], VERSION, search_query4, radius, LIMIT4)
url4
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SECRET&client_secret=SECRET&ll=43.3895633,-80.4051748&v=20180604&query=Restaurant&radius=5000&limit=100'

# %%
# Waterloo
results = requests.get(url).json()
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe for sushi restauraunts near University of Waterloo
df4 = json_normalize(venues)
df4.head(10)
# Out:
#                          id                       name  \
# 0  55afc40a498e44ca0990bbe9  168 Sushi Buffet Waterloo
# 1  4cfede82c86e5481ca91c74a  Watami Sushi and Sake Bar
# 2  5186dad4498ef49c8faaa9f4               Itamae Sushi
# 3  4df2068f22718759f8199648            Ah-So Sushi(DC)
# 4  4cb0fcb3562d224b1f611b88                   Sushi 99
# 5  5814fd2a38fa0816c5b07d09            KEN Sushi House
# 6  4b7f3268f964a520521e30e3                Sushi Stars
# 7  5fc8c33c542ed2502ccdda98                Bento Sushi
# 8  54fdd4cb498e23c1e6bf74ee                 Suki Sushi
# 9  5fb8e4f777761c518f22b7a9                Bento Sushi
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1612115561    False
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 3  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1612115561    False
# 4  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 5  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 6  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 7  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115561    False
# 8  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 9  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115561    False
#
#               location.address  location.lat  location.lng  \
# 0       D4-5 50 Westmount Rd N     43.461442    -80.538030
# 1                 15 King St N     43.465538    -80.522496
# 2                235 King St N     43.476728    -80.525298
# 3                          NaN     43.473107    -80.542896
# 4  36 Northfield Dr E, Unit 12     43.503426    -80.530820
# 5               256 Phillip St     43.473483    -80.537197
# 6              450 King St. E.     43.446617    -80.481674
# 7    75 University Avenue West     43.473557    -80.528737
# 8                 345 Erb st w     43.455146    -80.546067
# 9     450 Columbia Street West     43.467967    -80.568014
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.46144233288407...               1160
# 1  [{'label': 'display', 'lat': 43.46553769056703...               1754
# 2  [{'label': 'display', 'lat': 43.47672824448561...               1531
# 3  [{'label': 'display', 'lat': 43.473107, 'lng':...                201
# 4  [{'label': 'display', 'lat': 43.50342570876072...               3703
# 5  [{'label': 'display', 'lat': 43.47348313080127...                507
# 6  [{'label': 'display', 'lat': 43.44661711801076...               5645
# 7  [{'label': 'display', 'lat': 43.47355729088632...               1156
# 8  [{'label': 'display', 'lat': 43.45514627147399...               1818
# 9  [{'label': 'display', 'lat': 43.4679668, 'lng'...               2077
#
#   location.postalCode location.cc location.city location.state  \
# 0             N2L 6N9          CA      Waterloo             ON
# 1             N2J 2W6          CA      Waterloo             ON
# 2             N2J 2Y8          CA      Waterloo             ON
# 3                 NaN          CA      Waterloo             ON
# 4             N2L 6A1          CA      Waterloo             ON
# 5                 NaN          CA      Waterloo             ON
# 6             N2L 2L6          CA     Kitchener             ON
# 7             N2L 3C5          CA      Waterloo             ON
# 8             N2L 1W4          CA      Waterloo             ON
# 9             N2T 2W1          CA      Waterloo             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [D4-5 50 Westmount Rd N, Waterloo ON N2L 6N9, ...
# 1           Canada  [15 King St N (at Erb St W), Waterloo ON N2J 2...
# 2           Canada  [235 King St N (at University Ave), Waterloo O...
# 3           Canada                              [Waterloo ON, Canada]
# 4           Canada  [36 Northfield Dr E, Unit 12 (at King St N), W...
# 5           Canada  [256 Phillip St (at University Av W), Waterloo...
# 6           Canada  [450 King St. E. (at Madison Ave. N.), Kitchen...
# 7           Canada  [75 University Avenue West, Waterloo ON N2L 3C...
# 8           Canada        [345 Erb st w, Waterloo ON N2L 1W4, Canada]
# 9           Canada  [450 Columbia Street West, Waterloo ON N2T 2W1...
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1          at Erb St W          NaN
# 2    at University Ave          NaN
# 3                  NaN          NaN
# 4         at King St N          NaN
# 5   at University Av W          NaN
# 6   at Madison Ave. N.          NaN
# 7                  NaN          NaN
# 8                  NaN          NaN
# 9                  NaN    603175342

# %%
# Kitchener
results2 = requests.get(url2).json()
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# tranform venues into a dataframe for sushi restauraunts near Conestoga College
df7 = json_normalize(venues2)
df7.head()
# Out:
#                          id           name  \
# 0  5fb3a233a66ece2fc3d58234    Bento Sushi
# 1  5fb3a4910c6f00024fd23196    Bento Sushi
# 2  4c252bf7f1272d7ffd5584c5     Ye's Sushi
# 3  4f2181d1e4b0b69d789b9a4f     Doon Sushi
# 4  517af2d7e4b0696131ca30ca  Lin Hai Sushi
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115561    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115561    False
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 3  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
# 4  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1612115561    False
#
#         location.address  location.lat  location.lng  \
# 0  299 Doon Valley Drive     43.389864    -80.404782
# 1      123 Pioneer Drive     43.393963    -80.432003
# 2      70 Sportsworld Dr     43.409135    -80.393169
# 3  601 Doon Village Road     43.398301    -80.446285
# 4          1401 River Rd     43.433847    -80.427809
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.3898641, 'lng'...                 46
# 1  [{'label': 'display', 'lat': 43.39396259999999...               2224
# 2  [{'label': 'display', 'lat': 43.40913477264124...               2385
# 3  [{'label': 'display', 'lat': 43.39830101789896...               3464
# 4  [{'label': 'display', 'lat': 43.433847, 'lng':...               5258
#
#   location.postalCode location.cc location.city location.state  \
# 0             N2G 4M4          CA     Kitchener             ON
# 1             N2P 1K8          CA     Kitchener             ON
# 2                 NaN          CA     Kitchener             ON
# 3                 NaN          CA     Kitchener             ON
# 4             N2A 3X9          CA     Kitchener             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [299 Doon Valley Drive, Kitchener ON N2G 4M4, ...
# 1           Canada  [123 Pioneer Drive, Kitchener ON N2P 1K8, Canada]
# 2           Canada  [70 Sportsworld Dr (at Gateway Park Dr), Kitch...
# 3           Canada  [601 Doon Village Road (Homer Watson Blvd), Ki...
# 4           Canada      [1401 River Rd, Kitchener ON N2A 3X9, Canada]
#
#   venuePage.id location.crossStreet
# 0    597164227                  NaN
# 1    602422090                  NaN
# 2          NaN   at Gateway Park Dr
# 3          NaN    Homer Watson Blvd
# 4          NaN                  NaN

# %%
# All Waterloo
results3 = requests.get(url3).json()
# assign relevant part of JSON to venues
venues3 = results3['response']['venues']

# tranform venues into a dataframe for restauraunts near Waterloo University
df5 = json_normalize(venues3)
df5.head(20)
# Out:
#                           id                                        name  \
# 0   4e2df16952b111a1e374f9a3                      Chen's Restaurant 橙子餐廳
# 1   579e766ccd102f2ed7a0e778                  King Tin Restaurant 瓊天海鮮酒家
# 2   4b631946f964a520d6622ae3                Solé Restaurant and Wine Bar
# 3   4b6c71ebf964a520ad3a2ce3            Crystal Palace Restaurant 美味棧粵菜館
# 4   4b549552f964a52020c127e3          Symposium Café Restaurant & Lounge
# 5   4b96bb77f964a520ebe034e3          Jia Jia Lok Chinese Restaurant 家家樂
# 6   5356d10c11d2bbfbf6721509               Friends' Home Restaurant 友家餐廳
# 7   518fa5aa498e31f5de9f327c                             Silo Restaurant
# 8   5b5a4928a5a315002ca35ec8                    Mr. S Yin Restaurant 尹師傅
# 9   4b200a97f964a5207b2c24e3                           Kismet Restaurant
# 10  594088a51cf2e108a4c6b31f              Kw Students Delight Restaurant
# 11  4b003747f964a520953b22e3  Cameron Chinese Seafood Restaurant 金麗豪海鮮酒家
# 12  596d304eb1538e4ee5bd324e                       Kuro Restaurant & Bar
# 13  4efb957a775bec1428c2b0f1             Bogda Uyghur Cuisine Restaurant
# 14  4e5a534eb0fbdca30a092712    Da Vinci Café Bar, Restaurant & Pizzeria
# 15  4d92640d7ac3a35da21ec025                       J&B Family Restaurant
# 16  4b731aeff964a520bd9b2de3                     Wilf's Restaurant & Bar
# 17  4b64f349f964a520d9db2ae3                     Lion Brewery Restaurant
# 18  4fae50e1e4b08260e3d62ee5                               My Restaurant
# 19  4b06fbbcf964a520c4f422e3               China Garden Restaurant 食德喜小館
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
# 1   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
# 2   [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1612115562    False
# 3   [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1612115562    False
# 4   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 5   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
# 6   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
# 7   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1612115562    False
# 8   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
# 9   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1612115562    False
# 10  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1612115562    False
# 11  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1612115562    False
# 12  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  v-1612115562    False
# 13  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1612115562    False
# 14  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 15  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 16  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 17  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...  v-1612115562    False
# 18  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 19  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1612115562    False
#
#                          location.address        location.crossStreet  \
# 0                    170 University Ave W               at Phillip St
# 1                       318 Spruce Street                         NaN
# 2                             83 Erb St W      Father David Bauer Dr.
# 3                            10 King St S        btw Erb & Willis Way
# 4                            4 King St. N                     Erb St.
# 5                       255 King Street N         at University Ave W
# 6                           402 King St N                       Weber
# 7                          115 N Water St                         NaN
# 8                                     NaN                         NaN
# 9                    160 University Ave W              at Phillip St.
# 10                                    NaN                         NaN
# 11                        19 Cameron St S               at Charles St
# 12               Units A&B, 222 Albert St          at University Av W
# 13                           62 Balsam St                    Hazel St
# 14                         21 Weber St. W            at Ontario St. N
# 15                       79 Victoria St N                         NaN
# 16  75 University Ave. W., 1st Floor FNCC  Fred Nichols Campus Centre
# 17                           59 King St N                         NaN
# 18                                    NaN                         NaN
# 19                  31 University Ave. E.               at Regina St.
#
#     location.lat  location.lng  \
# 0      43.472201    -80.538936
# 1      43.479122    -80.526460
# 2      43.463539    -80.527127
# 3      43.464900    -80.522269
# 4      43.465226    -80.522108
# 5      43.477514    -80.525377
# 6      43.484400    -80.526300
# 7      43.468016    -80.546047
# 8      43.472360    -80.535995
# 9      43.472591    -80.537194
# 10     43.475815    -80.535970
# 11     43.445460    -80.481039
# 12     43.474036    -80.531530
# 13     43.467741    -80.593564
# 14     43.452092    -80.488578
# 15     43.454125    -80.494698
# 16     43.473512    -80.528578
# 17     43.466856    -80.523135
# 18     43.456874    -80.542003
# 19     43.476797    -80.523271
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.47220145197439...                321
# 1   [{'label': 'display', 'lat': 43.479122, 'lng':...               1575
# 2   [{'label': 'display', 'lat': 43.463539, 'lng':...               1527
# 3   [{'label': 'display', 'lat': 43.4648999041143,...               1798
# 4   [{'label': 'display', 'lat': 43.46522635075343...               1796
# 5   [{'label': 'display', 'lat': 43.47751412754712...               1562
# 6   [{'label': 'display', 'lat': 43.4844, 'lng': -...               1971
# 7   [{'label': 'display', 'lat': 43.468016, 'lng':...                453
# 8   [{'label': 'display', 'lat': 43.47236, 'lng': ...                555
# 9   [{'label': 'display', 'lat': 43.47259104627461...                468
# 10  [{'label': 'display', 'lat': 43.475815, 'lng':...                741
# 11  [{'label': 'display', 'lat': 43.44545959408337...               5754
# 12  [{'label': 'display', 'lat': 43.474036, 'lng':...                953
# 13  [{'label': 'display', 'lat': 43.4677409544014,...               4127
# 14  [{'label': 'display', 'lat': 43.452092, 'lng':...               4868
# 15  [{'label': 'display', 'lat': 43.4541250149002,...               4325
# 16  [{'label': 'display', 'lat': 43.47351159612270...               1168
# 17  [{'label': 'display', 'lat': 43.46685636390227...               1657
# 18  [{'label': 'display', 'lat': 43.456874, 'lng':...               1606
# 19  [{'label': 'display', 'lat': 43.47679668816249...               1685
#
#    location.postalCode location.cc location.city location.state  \
# 0              N2L 3E9          CA      Waterloo             ON
# 1              N2L 3M7          CA      Waterloo             ON
# 2              N2L 6C2          CA      Waterloo             ON
# 3              N2J 1N8          CA      Waterloo             ON
# 4              N2J 2W7          CA      Waterloo             ON
# 5              N2J 4V2          CA      Waterloo             ON
# 6                  NaN          CA      Waterloo             ON
# 7                14092          CA      Lewiston             NY
# 8              N2L 6J3          CA      Waterloo             ON
# 9              N2L 3E9          CA      Waterloo             ON
# 10             N2L 3J8          CA      Waterloo             ON
# 11             N2G 2P8          CA     Kitchener             ON
# 12             N2L 3T6          CA      Waterloo             ON
# 13             N2L 3H2          CA      Waterloo             ON
# 14             N2H 3Y9          CA     Kitchener             ON
# 15                 NaN          CA     Kitchener             ON
# 16             N2L 3C5          CA      Waterloo             ON
# 17             N2J 2X2          CA      Waterloo             ON
# 18                 NaN          CA           NaN            NaN
# 19             N2J 2V9          CA      Waterloo             ON
#
#    location.country                          location.formattedAddress  \
# 0            Canada  [170 University Ave W (at Phillip St), Waterlo...
# 1            Canada   [318 Spruce Street, Waterloo ON N2L 3M7, Canada]
# 2            Canada  [83 Erb St W (Father David Bauer Dr.), Waterlo...
# 3            Canada  [10 King St S (btw Erb & Willis Way), Waterloo...
# 4            Canada  [4 King St. N (Erb St.), Waterloo ON N2J 2W7, ...
# 5            Canada  [255 King Street N (at University Ave W), Wate...
# 6            Canada       [402 King St N (Weber), Waterloo ON, Canada]
# 7            Canada        [115 N Water St, Lewiston NY 14092, Canada]
# 8            Canada                      [Waterloo ON N2L 6J3, Canada]
# 9            Canada  [160 University Ave W (at Phillip St.), Waterl...
# 10           Canada                      [Waterloo ON N2L 3J8, Canada]
# 11           Canada  [19 Cameron St S (at Charles St), Kitchener ON...
# 12           Canada  [Units A&B, 222 Albert St (at University Av W)...
# 13           Canada  [62 Balsam St (Hazel St), Waterloo ON N2L 3H2,...
# 14           Canada  [21 Weber St. W (at Ontario St. N), Kitchener ...
# 15           Canada           [79 Victoria St N, Kitchener ON, Canada]
# 16           Canada  [75 University Ave. W., 1st Floor FNCC (Fred N...
# 17           Canada        [59 King St N, Waterloo ON N2J 2X2, Canada]
# 18           Canada                                           [Canada]
# 19           Canada  [31 University Ave. E. (at Regina St.), Waterl...
#
#    venuePage.id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4     146437950
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN

# %%
# All Kitchener
results4 = requests.get(url4).json()
# assign relevant part of JSON to venues
venues4 = results4['response']['venues']

# tranform venues into a dataframe for restauraunts near Conestoga College
df8 = json_normalize(venues4)
df8.head(10)
# Out:
#                          id  \
# 0  4bcccd148920b713d9c59edc
# 1  56c2632dcd108bebe43a5dd4
# 2  57c74fea498e24c106a0bc6f
# 3  4c4b0122c668e21e9f4274f9
# 4  4cbb24c19552b60cc838de8b
# 5  4d0f3e5271e8a1cd749679bd
# 6  4b7c7470f964a52088942fe3
# 7  5fe03385e80f01698ae8fe9d
# 8  4c0aee3732daef3bb3bc4b50
# 9  5674975f498e98ce88afe43e
#
#                                                 name  \
# 0                            Modern India Restaurant
# 1                             Bombay Bhel Restaurant
# 2                         Genesis Spanish Restaurant
# 3                        Cambridge Family Restaurant
# 4                               Cambridge Restaurant
# 5                                   Eagle Restaurant
# 6                                Shanghai Restaurant
# 7  HomeTaste - Indian Restaurant, Catering and Ti...
# 8                               Martini's restaurant
# 9                             126 Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1612115562    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1612115562    False
# 2  [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1612115562    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
# 4                                                 []  v-1612115562    False
# 5  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...  v-1612115562    False
# 6                                                 []  v-1612115562    False
# 7  [{'id': '54135bf5e4b08f3d2429dfdd', 'name': 'N...  v-1612115562    False
# 8  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1612115562    False
# 9  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612115562    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0         4355 King St E    at Sportsworld Dr     43.406960    -80.396880
# 1  4336 King Street East        Hellmann Road     43.407860    -80.396372
# 2                    NaN                  NaN     43.398587    -80.363134
# 3      752 King st, East                  NaN     43.395407    -80.357521
# 4        752 king street                  NaN     43.395376    -80.357562
# 5   1390 Eagle Street N.           Concession     43.404948    -80.347585
# 6            King Street                Chuch     43.395262    -80.357426
# 7     1601 River Rd East                  NaN     43.428770    -80.422145
# 8      2980 king st east                  NaN     43.428779    -80.432767
# 9         2922 King St E        King & Morgan     43.429418    -80.435049
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.40696016679312...               2049
# 1  [{'label': 'display', 'lat': 43.40786, 'lng': ...               2157
# 2  [{'label': 'display', 'lat': 43.398587, 'lng':...               3545
# 3  [{'label': 'display', 'lat': 43.395407, 'lng':...               3909
# 4  [{'label': 'display', 'lat': 43.395376, 'lng':...               3905
# 5  [{'label': 'display', 'lat': 43.40494822033108...               4962
# 6  [{'label': 'display', 'lat': 43.395262, 'lng':...               3914
# 7  [{'label': 'display', 'lat': 43.42876975908951...               4575
# 8  [{'label': 'display', 'lat': 43.42877888348605...               4902
# 9  [{'label': 'display', 'lat': 43.429418, 'lng':...               5051
#
#   location.postalCode location.cc location.city location.state  \
# 0             N2P 2E9          CA     Kitchener             ON
# 1             N2P 3W6          CA     Kitchener             ON
# 2                 NaN          CA           NaN            NaN
# 3              N3h3n9          CA     Cambridge             ON
# 4                 NaN          CA     Cambridge             ON
# 5                 NaN          CA     Cambridge             ON
# 6                 NaN          CA     Cambridge             ON
# 7             N2A 3Y4          CA     Kitchener             ON
# 8             N2A 1A9          CA     Kitchener             ON
# 9             N2A 1A7          CA     Kitchener             ON
#
#   location.country                          location.formattedAddress
# 0           Canada  [4355 King St E (at Sportsworld Dr), Kitchener...
# 1           Canada  [4336 King Street East (Hellmann Road), Kitche...
# 2           Canada                                           [Canada]
# 3           Canada   [752 King st, East, Cambridge ON N3h3n9, Canada]
# 4           Canada            [752 king street, Cambridge ON, Canada]
# 5           Canada  [1390 Eagle Street N. (Concession), Cambridge ...
# 6           Canada        [King Street (Chuch), Cambridge ON, Canada]
# 7           Canada  [1601 River Rd East, Kitchener ON N2A 3Y4, Can...
# 8           Canada  [2980 king st east, Kitchener ON N2A 1A9, Canada]
# 9           Canada  [2922 King St E (King & Morgan), Kitchener ON ...

# %%
#Waterloo 
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df4.columns if col.startswith('location.')] + ['id']
df4_filtered = df4.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df4_filtered['categories'] = df4_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df4_filtered.columns = [column.split('.')[-1] for column in df4_filtered.columns]

df4_filtered
# Out:
#                          name           categories  \
# 0   168 Sushi Buffet Waterloo     Sushi Restaurant
# 1   Watami Sushi and Sake Bar  Japanese Restaurant
# 2                Itamae Sushi     Sushi Restaurant
# 3             Ah-So Sushi(DC)  Japanese Restaurant
# 4                    Sushi 99     Sushi Restaurant
# 5             KEN Sushi House     Sushi Restaurant
# 6                 Sushi Stars     Sushi Restaurant
# 7                 Bento Sushi           Restaurant
# 8                  Suki Sushi     Sushi Restaurant
# 9                 Bento Sushi           Restaurant
# 10                Bento Sushi     Sushi Restaurant
# 11            Wasabi! @UWFeds     Sushi Restaurant
# 12                Bento Sushi           Restaurant
# 13                Bento Sushi           Restaurant
# 14                Bento Sushi           Restaurant
# 15                Bento Sushi           Restaurant
# 16                Mac's Sushi     Sushi Restaurant
# 17                 Wild Sushi  Szechuan Restaurant
# 18                Bento Sushi           Restaurant
# 19                   Yo Sushi     Sushi Restaurant
# 20                Bento Sushi     Sushi Restaurant
# 21                 Nara Sushi     Sushi Restaurant
# 22                Ye's Buffet     Sushi Restaurant
# 23        Yummyaki Restaurant     Sushi Restaurant
#
#                          address        lat        lng  \
# 0         D4-5 50 Westmount Rd N  43.461442 -80.538030
# 1                   15 King St N  43.465538 -80.522496
# 2                  235 King St N  43.476728 -80.525298
# 3                            NaN  43.473107 -80.542896
# 4    36 Northfield Dr E, Unit 12  43.503426 -80.530820
# 5                 256 Phillip St  43.473483 -80.537197
# 6                450 King St. E.  43.446617 -80.481674
# 7      75 University Avenue West  43.473557 -80.528737
# 8                   345 Erb st w  43.455146 -80.546067
# 9       450 Columbia Street West  43.467967 -80.568014
# 10            94 Bridgeport Road  43.469483 -80.515968
# 11          200 University Ave W  43.471829 -80.545158
# 12           450 Erb Street West  43.453371 -80.555824
# 13            640 Parkside Drive  43.498793 -80.549574
# 14            555 Davenport Road  43.496855 -80.525060
# 15              315 Lincoln Road  43.483043 -80.506336
# 16                 550 King St N  43.497143 -80.526567
# 17  Unit B10, 619 Wild Ginger Av  43.469807 -80.594785
# 18        875 Highland Road West  43.429586 -80.526481
# 19                 103 king st w  43.450440 -80.491070
# 20          235 Ira Needles Blvd  43.424291 -80.553340
# 21    E-685 Fischer Hallman Road  43.415913 -80.511617
# 22                 583 King St N  43.501752 -80.533916
# 23            55 Northfield Dr E  43.502651 -80.527639
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.46144233288407...      1160    N2L 6N9
# 1   [{'label': 'display', 'lat': 43.46553769056703...      1754    N2J 2W6
# 2   [{'label': 'display', 'lat': 43.47672824448561...      1531    N2J 2Y8
# 3   [{'label': 'display', 'lat': 43.473107, 'lng':...       201        NaN
# 4   [{'label': 'display', 'lat': 43.50342570876072...      3703    N2L 6A1
# 5   [{'label': 'display', 'lat': 43.47348313080127...       507        NaN
# 6   [{'label': 'display', 'lat': 43.44661711801076...      5645    N2L 2L6
# 7   [{'label': 'display', 'lat': 43.47355729088632...      1156    N2L 3C5
# 8   [{'label': 'display', 'lat': 43.45514627147399...      1818    N2L 1W4
# 9   [{'label': 'display', 'lat': 43.4679668, 'lng'...      2077    N2T 2W1
# 10  [{'label': 'display', 'lat': 43.4694827400187,...      2170    N2J 2J4
# 11  [{'label': 'display', 'lat': 43.47182863681502...       205    N2L 3G1
# 12  [{'label': 'display', 'lat': 43.4533713, 'lng'...      2259    N2T 1A1
# 13  [{'label': 'display', 'lat': 43.4987928, 'lng'...      3110    N2L 5V4
# 14  [{'label': 'display', 'lat': 43.4968549, 'lng'...      3182    N2L 6L2
# 15  [{'label': 'display', 'lat': 43.4830426, 'lng'...      3216    N2J 4H7
# 16  [{'label': 'display', 'lat': 43.49714265334467...      3158    N2L 5W6
# 17  [{'label': 'display', 'lat': 43.4698074251162,...      4209    N2L 2X1
# 18  [{'label': 'display', 'lat': 43.4295865, 'lng'...      4825    N2N 2Y2
# 19  [{'label': 'display', 'lat': 43.45044, 'lng': ...      4775    N2G 1A7
# 20  [{'label': 'display', 'lat': 43.4242914719911,...      5302    N2N 0B2
# 21  [{'label': 'display', 'lat': 43.41591283107812...      6658        NaN
# 22  [{'label': 'display', 'lat': 43.50175168096994...      3463    N2V 2E5
# 23  [{'label': 'display', 'lat': 43.50265140320883...      3696    N2K 3T6
#
#     cc       city state country  \
# 0   CA   Waterloo    ON  Canada
# 1   CA   Waterloo    ON  Canada
# 2   CA   Waterloo    ON  Canada
# 3   CA   Waterloo    ON  Canada
# 4   CA   Waterloo    ON  Canada
# 5   CA   Waterloo    ON  Canada
# 6   CA  Kitchener    ON  Canada
# 7   CA   Waterloo    ON  Canada
# 8   CA   Waterloo    ON  Canada
# 9   CA   Waterloo    ON  Canada
# 10  CA   Waterloo    ON  Canada
# 11  CA   Waterloo    ON  Canada
# 12  CA   Waterloo    ON  Canada
# 13  CA   Waterloo    ON  Canada
# 14  CA   Waterloo    ON  Canada
# 15  CA   Waterloo    ON  Canada
# 16  CA   Waterloo    ON  Canada
# 17  CA   Waterloo    ON  Canada
# 18  CA  Kitchener    ON  Canada
# 19  CA  Kitchener    ON  Canada
# 20  CA  Kitchener    ON  Canada
# 21  CA  Kitchener    ON  Canada
# 22  CA   Waterloo    ON  Canada
# 23  CA   Waterloo    ON  Canada
#
#                                      formattedAddress  \
# 0   [D4-5 50 Westmount Rd N, Waterloo ON N2L 6N9, ...
# 1   [15 King St N (at Erb St W), Waterloo ON N2J 2...
# 2   [235 King St N (at University Ave), Waterloo O...
# 3                               [Waterloo ON, Canada]
# 4   [36 Northfield Dr E, Unit 12 (at King St N), W...
# 5   [256 Phillip St (at University Av W), Waterloo...
# 6   [450 King St. E. (at Madison Ave. N.), Kitchen...
# 7   [75 University Avenue West, Waterloo ON N2L 3C...
# 8         [345 Erb st w, Waterloo ON N2L 1W4, Canada]
# 9   [450 Columbia Street West, Waterloo ON N2T 2W1...
# 10  [94 Bridgeport Road, Waterloo ON N2J 2J4, Canada]
# 11  [200 University Ave W, Waterloo ON N2L 3G1, Ca...
# 12  [450 Erb Street West, Waterloo ON N2T 1A1, Can...
# 13  [640 Parkside Drive, Waterloo ON N2L 5V4, Canada]
# 14  [555 Davenport Road, Waterloo ON N2L 6L2, Canada]
# 15    [315 Lincoln Road, Waterloo ON N2J 4H7, Canada]
# 16       [550 King St N, Waterloo ON N2L 5W6, Canada]
# 17  [Unit B10, 619 Wild Ginger Av, Waterloo ON N2L...
# 18  [875 Highland Road West, Kitchener ON N2N 2Y2,...
# 19      [103 king st w, Kitchener ON N2G 1A7, Canada]
# 20  [235 Ira Needles Blvd, Kitchener ON N2N 0B2, C...
# 21  [E-685 Fischer Hallman Road (Fisher-hallman an...
# 22  [583 King St N (Northfield), Waterloo ON N2V 2...
# 23  [55 Northfield Dr E (at Davenport Rd), Waterlo...
#
#                       crossStreet                        id
# 0                             NaN  55afc40a498e44ca0990bbe9
# 1                     at Erb St W  4cfede82c86e5481ca91c74a
# 2               at University Ave  5186dad4498ef49c8faaa9f4
# 3                             NaN  4df2068f22718759f8199648
# 4                    at King St N  4cb0fcb3562d224b1f611b88
# 5              at University Av W  5814fd2a38fa0816c5b07d09
# 6              at Madison Ave. N.  4b7f3268f964a520521e30e3
# 7                             NaN  5fc8c33c542ed2502ccdda98
# 8                             NaN  54fdd4cb498e23c1e6bf74ee
# 9                             NaN  5fb8e4f777761c518f22b7a9
# 10                            NaN  5c2ddf1f31fd140039620e8d
# 11                            NaN  4cced31332e776b06299dc27
# 12                            NaN  5fb8e55a7ea19345f2520fdb
# 13                            NaN  5fb3a3b58491485722d055d0
# 14                            NaN  5fb3a4945858a34bc22275ee
# 15                            NaN  5fb3a49525f1c3092e6198c1
# 16                            NaN  4c324c3a7cc0c9b65f15f09a
# 17                            NaN  559ab4c0498e6059956c2cc3
# 18                            NaN  5fb3a4a57827692d0bb827c1
# 19                            NaN  5b70b0783af988002c11b409
# 20                            NaN  5bffea76d69ed0002cadc91b
# 21  Fisher-hallman and Ottawa St.  4cf6ddf5c28df04d4555cd15
# 22                     Northfield  4af1c2f9f964a520eee221e3
# 23                at Davenport Rd  4bc0ea4b4cdfc9b658c39321

# %%
#Kitchener
# keep only columns that include venue name, and anything that is associated with location
filtered_columns2 = ['name', 'categories'] + [col for col in df7.columns if col.startswith('location.')] + ['id']
df7_filtered = df7.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type2(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df7_filtered['categories'] = df7_filtered.apply(get_category_type2, axis=1)

# clean column names by keeping only last term
df7_filtered.columns = [column.split('.')[-1] for column in df7_filtered.columns]

df7_filtered
# Out:
#             name        categories                address        lat  \
# 0    Bento Sushi        Restaurant  299 Doon Valley Drive  43.389864
# 1    Bento Sushi        Restaurant      123 Pioneer Drive  43.393963
# 2     Ye's Sushi  Sushi Restaurant      70 Sportsworld Dr  43.409135
# 3     Doon Sushi  Sushi Restaurant  601 Doon Village Road  43.398301
# 4  Lin Hai Sushi  Sushi Restaurant          1401 River Rd  43.433847
#
#          lng                                     labeledLatLngs  distance  \
# 0 -80.404782  [{'label': 'display', 'lat': 43.3898641, 'lng'...        46
# 1 -80.432003  [{'label': 'display', 'lat': 43.39396259999999...      2224
# 2 -80.393169  [{'label': 'display', 'lat': 43.40913477264124...      2385
# 3 -80.446285  [{'label': 'display', 'lat': 43.39830101789896...      3464
# 4 -80.427809  [{'label': 'display', 'lat': 43.433847, 'lng':...      5258
#
#   postalCode  cc       city state country  \
# 0    N2G 4M4  CA  Kitchener    ON  Canada
# 1    N2P 1K8  CA  Kitchener    ON  Canada
# 2        NaN  CA  Kitchener    ON  Canada
# 3        NaN  CA  Kitchener    ON  Canada
# 4    N2A 3X9  CA  Kitchener    ON  Canada
#
#                                     formattedAddress         crossStreet  \
# 0  [299 Doon Valley Drive, Kitchener ON N2G 4M4, ...                 NaN
# 1  [123 Pioneer Drive, Kitchener ON N2P 1K8, Canada]                 NaN
# 2  [70 Sportsworld Dr (at Gateway Park Dr), Kitch...  at Gateway Park Dr
# 3  [601 Doon Village Road (Homer Watson Blvd), Ki...   Homer Watson Blvd
# 4      [1401 River Rd, Kitchener ON N2A 3X9, Canada]                 NaN
#
#                          id
# 0  5fb3a233a66ece2fc3d58234
# 1  5fb3a4910c6f00024fd23196
# 2  4c252bf7f1272d7ffd5584c5
# 3  4f2181d1e4b0b69d789b9a4f
# 4  517af2d7e4b0696131ca30ca

# %%
#All Near Waterloo
# keep only columns that include venue name, and anything that is associated with location
filtered_columns3 = ['name', 'categories'] + [col for col in df5.columns if col.startswith('location.')] + ['id']
df5_filtered = df5.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type3(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df5_filtered['categories'] = df5_filtered.apply(get_category_type3, axis=1)

# clean column names by keeping only last term
df5_filtered.columns = [column.split('.')[-1] for column in df5_filtered.columns]

df5_filtered
# Out:
#                                           name                   categories  \
# 0                       Chen's Restaurant 橙子餐廳           Chinese Restaurant
# 1                   King Tin Restaurant 瓊天海鮮酒家           Chinese Restaurant
# 2                 Solé Restaurant and Wine Bar                     Wine Bar
# 3             Crystal Palace Restaurant 美味棧粵菜館           Dim Sum Restaurant
# 4           Symposium Café Restaurant & Lounge                   Restaurant
# 5           Jia Jia Lok Chinese Restaurant 家家樂           Chinese Restaurant
# 6                Friends' Home Restaurant 友家餐廳           Chinese Restaurant
# 7                              Silo Restaurant          American Restaurant
# 8                     Mr. S Yin Restaurant 尹師傅           Chinese Restaurant
# 9                            Kismet Restaurant            Indian Restaurant
# 10              Kw Students Delight Restaurant            Indian Restaurant
# 11  Cameron Chinese Seafood Restaurant 金麗豪海鮮酒家           Dim Sum Restaurant
# 12                       Kuro Restaurant & Bar          Japanese Restaurant
# 13             Bogda Uyghur Cuisine Restaurant             Asian Restaurant
# 14    Da Vinci Café Bar, Restaurant & Pizzeria                   Restaurant
# 15                       J&B Family Restaurant                   Restaurant
# 16                     Wilf's Restaurant & Bar                   Restaurant
# 17                     Lion Brewery Restaurant            German Restaurant
# 18                               My Restaurant                   Restaurant
# 19               China Garden Restaurant 食德喜小館           Chinese Restaurant
# 20                         Yummyaki Restaurant             Sushi Restaurant
# 21              Checkerboard Family Restaurant               Breakfast Spot
# 22                         Dearborn Restaurant               Breakfast Spot
# 23    Owl Of Minerva Korean Restaurant And Bar            Korean Restaurant
# 24                   Ming's Chinese Restaurant           Chinese Restaurant
# 25                          New Sky Restaurant                         None
# 26                                    Harvey's                   Restaurant
# 27                           Waterloo Star 同德園           Chinese Restaurant
# 28                    Jack's Family Restaurant               Breakfast Spot
# 29                                 Dairy Queen               Ice Cream Shop
# 30                          Exclamation Fusion         Cantonese Restaurant
# 31                            Bud's Restaurant                        Diner
# 32             Angel's Diner Family Restaurant               Breakfast Spot
# 33                          Sorena Kebab House           Persian Restaurant
# 34                 Kim Seng Seafood Restaurant                         None
# 35                    SoCold Restaurant Supply         Kitchen Supply Store
# 36                  Joey's Seafood Restaurants           Seafood Restaurant
# 37                    Lucky Garden Restaurants                   Restaurant
# 38                     Alan Chinese Restaurant           Chinese Restaurant
# 39                     Lee Restaurant, Toronto          Moroccan Restaurant
# 40          Symposium Cafe Restaurant & Lounge               Breakfast Spot
# 41                   Tandoori Taste Restaurant            Indian Restaurant
# 42                             Gilt Restaurant                   Restaurant
# 43                   Veslo's Family Restaurant  Eastern European Restaurant
# 44                       St. George Restaurant                   Restaurant
# 45                      Frederick's Restaurant          American Restaurant
# 46                Prime Bar-B-Q Restaurant Ltd                   Restaurant
# 47                           Slices Restaurant                        Diner
# 48               Transfers Restaurant & lounge                          Bar
# 49                Pupuseria Latinos Restaurant    Latin American Restaurant
#
#                                   address        lat        lng  \
# 0                    170 University Ave W  43.472201 -80.538936
# 1                       318 Spruce Street  43.479122 -80.526460
# 2                             83 Erb St W  43.463539 -80.527127
# 3                            10 King St S  43.464900 -80.522269
# 4                            4 King St. N  43.465226 -80.522108
# 5                       255 King Street N  43.477514 -80.525377
# 6                           402 King St N  43.484400 -80.526300
# 7                          115 N Water St  43.468016 -80.546047
# 8                                     NaN  43.472360 -80.535995
# 9                    160 University Ave W  43.472591 -80.537194
# 10                                    NaN  43.475815 -80.535970
# 11                        19 Cameron St S  43.445460 -80.481039
# 12               Units A&B, 222 Albert St  43.474036 -80.531530
# 13                           62 Balsam St  43.467741 -80.593564
# 14                         21 Weber St. W  43.452092 -80.488578
# 15                       79 Victoria St N  43.454125 -80.494698
# 16  75 University Ave. W., 1st Floor FNCC  43.473512 -80.528578
# 17                           59 King St N  43.466856 -80.523135
# 18                                    NaN  43.456874 -80.542003
# 19                  31 University Ave. E.  43.476797 -80.523271
# 20                     55 Northfield Dr E  43.502651 -80.527639
# 21                      705 Belmont Ave W  43.453673 -80.518482
# 22                       105 Lexington Rd  43.486596 -80.517580
# 23                            2 King St N  43.465359 -80.522242
# 24                      465 Philip street  43.484245 -80.540723
# 25                                    NaN  43.480577 -80.521926
# 26           170 University Ave W Unit 10  43.471838 -80.538861
# 27                   170 University Ave W  43.472703 -80.537582
# 28                        20 Benjamin Rd.  43.508433 -80.555963
# 29    50 Westmount Rd N,50 Westmount Rd N  43.461661 -80.537073
# 30                        63 Hickory St W  43.477320 -80.530888
# 31                          219 Louisa St  43.458053 -80.494779
# 32                                    NaN  43.438860 -80.520967
# 33    220 King St North, Waterloo, Unit B  43.475750 -80.524507
# 34                         11 Westwood Dr  43.446751 -80.522765
# 35                        580 Colby Dr #3  43.500534 -80.537430
# 36                   12-370 Highland Rd W  43.438036 -80.510461
# 37                       101 Hazelglen Dr  43.440460 -80.526737
# 38                       2-11 Westwood Dr  43.446281 -80.523146
# 39                                    NaN  43.459784 -80.496371
# 40                    668 Erb Street West  43.446002 -80.574659
# 41                        200 Highland Rd  43.440950 -80.506988
# 42               305 King St. W. Unit 102  43.451499 -80.494824
# 43                          100 Arnold St  43.467813 -80.484963
# 44                                    NaN  43.508994 -80.543026
# 45                                    NaN  43.450405 -80.486967
# 46                      550 Highland Rd W  43.435513 -80.516581
# 47                        300 King St. W.  43.451848 -80.494652
# 48                                    NaN  43.449314 -80.492222
# 49                          23 Eby St. S.  43.447189 -80.484991
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.47220145197439...       321    N2L 3E9
# 1   [{'label': 'display', 'lat': 43.479122, 'lng':...      1575    N2L 3M7
# 2   [{'label': 'display', 'lat': 43.463539, 'lng':...      1527    N2L 6C2
# 3   [{'label': 'display', 'lat': 43.4648999041143,...      1798    N2J 1N8
# 4   [{'label': 'display', 'lat': 43.46522635075343...      1796    N2J 2W7
# 5   [{'label': 'display', 'lat': 43.47751412754712...      1562    N2J 4V2
# 6   [{'label': 'display', 'lat': 43.4844, 'lng': -...      1971        NaN
# 7   [{'label': 'display', 'lat': 43.468016, 'lng':...       453      14092
# 8   [{'label': 'display', 'lat': 43.47236, 'lng': ...       555    N2L 6J3
# 9   [{'label': 'display', 'lat': 43.47259104627461...       468    N2L 3E9
# 10  [{'label': 'display', 'lat': 43.475815, 'lng':...       741    N2L 3J8
# 11  [{'label': 'display', 'lat': 43.44545959408337...      5754    N2G 2P8
# 12  [{'label': 'display', 'lat': 43.474036, 'lng':...       953    N2L 3T6
# 13  [{'label': 'display', 'lat': 43.4677409544014,...      4127    N2L 3H2
# 14  [{'label': 'display', 'lat': 43.452092, 'lng':...      4868    N2H 3Y9
# 15  [{'label': 'display', 'lat': 43.4541250149002,...      4325        NaN
# 16  [{'label': 'display', 'lat': 43.47351159612270...      1168    N2L 3C5
# 17  [{'label': 'display', 'lat': 43.46685636390227...      1657    N2J 2X2
# 18  [{'label': 'display', 'lat': 43.456874, 'lng':...      1606        NaN
# 19  [{'label': 'display', 'lat': 43.47679668816249...      1685    N2J 2V9
# 20  [{'label': 'display', 'lat': 43.50265140320883...      3696    N2K 3T6
# 21  [{'label': 'display', 'lat': 43.453673, 'lng':...      2771    N2M 1P1
# 22  [{'label': 'display', 'lat': 43.48659638716064...      2649    N2J 4R7
# 23  [{'label': 'display', 'lat': 43.46535896487901...      1781    N2J 1N9
# 24  [{'label': 'display', 'lat': 43.48424480922014...      1450        N2L
# 25  [{'label': 'display', 'lat': 43.480577, 'lng':...      1971        NaN
# 26  [{'label': 'display', 'lat': 43.47183774237268...       317    N2L 3E9
# 27  [{'label': 'display', 'lat': 43.47270252313667...       443        NaN
# 28  [{'label': 'display', 'lat': 43.50843323288315...      4269    N2V 2J9
# 29  [{'label': 'display', 'lat': 43.4616605, 'lng'...      1165    N2L 2R5
# 30  [{'label': 'display', 'lat': 43.47732, 'lng': ...      1167    N2L 3H2
# 31  [{'label': 'display', 'lat': 43.45805272283324...      4144    N2H 4C7
# 32  [{'label': 'display', 'lat': 43.43886, 'lng': ...      4016        NaN
# 33  [{'label': 'display', 'lat': 43.47575043093069...      1552    N2J 4V7
# 34  [{'label': 'display', 'lat': 43.446751, 'lng':...      3172    N2M 2K5
# 35  [{'label': 'display', 'lat': 43.500534, 'lng':...      3282    N2V 1A2
# 36  [{'label': 'display', 'lat': 43.438036, 'lng':...      4528    N2M 5J9
# 37  [{'label': 'display', 'lat': 43.44046, 'lng': ...      3667    N2M 5A2
# 38  [{'label': 'display', 'lat': 43.44628082649375...      3202    N2M 2K5
# 39  [{'label': 'display', 'lat': 43.459784, 'lng':...      3957        NaN
# 40  [{'label': 'display', 'lat': 43.44600232013294...      3820    N2T 2K8
# 41  [{'label': 'display', 'lat': 43.44094977546623...      4443    N2M 1Y9
# 42  [{'label': 'display', 'lat': 43.45149886411015...      4453        NaN
# 43  [{'label': 'display', 'lat': 43.46781271245206...      4681    N2H 6E2
# 44  [{'label': 'display', 'lat': 43.508994, 'lng':...      4196    N2J 4G8
# 45  [{'label': 'display', 'lat': 43.450405, 'lng':...      5069        NaN
# 46  [{'label': 'display', 'lat': 43.435513, 'lng':...      4508    N2M 5G3
# 47  [{'label': 'display', 'lat': 43.451848, 'lng':...      4446        NaN
# 48  [{'label': 'display', 'lat': 43.449314, 'lng':...      4757        NaN
# 49  [{'label': 'display', 'lat': 43.44718928377727...      5381    N2G 3K6
#
#     cc       city state country  \
# 0   CA   Waterloo    ON  Canada
# 1   CA   Waterloo    ON  Canada
# 2   CA   Waterloo    ON  Canada
# 3   CA   Waterloo    ON  Canada
# 4   CA   Waterloo    ON  Canada
# 5   CA   Waterloo    ON  Canada
# 6   CA   Waterloo    ON  Canada
# 7   CA   Lewiston    NY  Canada
# 8   CA   Waterloo    ON  Canada
# 9   CA   Waterloo    ON  Canada
# 10  CA   Waterloo    ON  Canada
# 11  CA  Kitchener    ON  Canada
# 12  CA   Waterloo    ON  Canada
# 13  CA   Waterloo    ON  Canada
# 14  CA  Kitchener    ON  Canada
# 15  CA  Kitchener    ON  Canada
# 16  CA   Waterloo    ON  Canada
# 17  CA   Waterloo    ON  Canada
# 18  CA        NaN   NaN  Canada
# 19  CA   Waterloo    ON  Canada
# 20  CA   Waterloo    ON  Canada
# 21  CA  Kitchener    ON  Canada
# 22  CA   Waterloo    ON  Canada
# 23  CA   Waterloo    ON  Canada
# 24  CA   Waterloo    ON  Canada
# 25  CA    Toronto    ON  Canada
# 26  CA   Waterloo    ON  Canada
# 27  CA   Waterloo    ON  Canada
# 28  CA   Waterloo    ON  Canada
# 29  CA   Waterloo    ON  Canada
# 30  CA   Waterloo    ON  Canada
# 31  CA  Kitchener    ON  Canada
# 32  CA  Kitchener    ON  Canada
# 33  CA   Waterloo    ON  Canada
# 34  CA  Kitchener    ON  Canada
# 35  CA   Waterloo    ON  Canada
# 36  CA  Kitchener    ON  Canada
# 37  CA  Kitchener    ON  Canada
# 38  CA   Waterloo    ON  Canada
# 39  CA  Kitchener    ON  Canada
# 40  CA   Waterloo    ON  Canada
# 41  CA  Kitchener    ON  Canada
# 42  CA  Kitchener    ON  Canada
# 43  CA  Kitchener    ON  Canada
# 44  CA   Waterloo    ON  Canada
# 45  CA        NaN   NaN  Canada
# 46  CA  Kitchener    ON  Canada
# 47  CA  Kitchener    ON  Canada
# 48  CA  Kitchener    ON  Canada
# 49  CA  Kitchener    ON  Canada
#
#                                      formattedAddress  \
# 0   [170 University Ave W (at Phillip St), Waterlo...
# 1    [318 Spruce Street, Waterloo ON N2L 3M7, Canada]
# 2   [83 Erb St W (Father David Bauer Dr.), Waterlo...
# 3   [10 King St S (btw Erb & Willis Way), Waterloo...
# 4   [4 King St. N (Erb St.), Waterloo ON N2J 2W7, ...
# 5   [255 King Street N (at University Ave W), Wate...
# 6        [402 King St N (Weber), Waterloo ON, Canada]
# 7         [115 N Water St, Lewiston NY 14092, Canada]
# 8                       [Waterloo ON N2L 6J3, Canada]
# 9   [160 University Ave W (at Phillip St.), Waterl...
# 10                      [Waterloo ON N2L 3J8, Canada]
# 11  [19 Cameron St S (at Charles St), Kitchener ON...
# 12  [Units A&B, 222 Albert St (at University Av W)...
# 13  [62 Balsam St (Hazel St), Waterloo ON N2L 3H2,...
# 14  [21 Weber St. W (at Ontario St. N), Kitchener ...
# 15           [79 Victoria St N, Kitchener ON, Canada]
# 16  [75 University Ave. W., 1st Floor FNCC (Fred N...
# 17        [59 King St N, Waterloo ON N2J 2X2, Canada]
# 18                                           [Canada]
# 19  [31 University Ave. E. (at Regina St.), Waterl...
# 20  [55 Northfield Dr E (at Davenport Rd), Waterlo...
# 21  [705 Belmont Ave W (btw Claremont & Union), Ki...
# 22    [105 Lexington Rd, Waterloo ON N2J 4R7, Canada]
# 23         [2 King St N, Waterloo ON N2J 1N9, Canada]
# 24       [465 Philip street, Waterloo ON N2L, Canada]
# 25              [Spadina/baldwin, Toronto ON, Canada]
# 26  [170 University Ave W Unit 10, Waterloo ON N2L...
# 27  [170 University Ave W (at Phillip St), Waterlo...
# 28  [20 Benjamin Rd. (at Farmers Market Rd.), Wate...
# 29  [50 Westmount Rd N,50 Westmount Rd N, Waterloo...
# 30  [63 Hickory St W (Hickory St W / Larch St), Wa...
# 31      [219 Louisa St, Kitchener ON N2H 4C7, Canada]
# 32                             [Kitchener ON, Canada]
# 33  [220 King St North, Waterloo, Unit B (King&Uni...
# 34     [11 Westwood Dr, Kitchener ON N2M 2K5, Canada]
# 35     [580 Colby Dr #3, Waterloo ON N2V 1A2, Canada]
# 36  [12-370 Highland Rd W (Lawrence Ave.), Kitchen...
# 37  [101 Hazelglen Dr (Chopin), Kitchener ON N2M 5...
# 38  [2-11 Westwood Dr (at Westmount Dr), Waterloo ...
# 39                             [Kitchener ON, Canada]
# 40  [668 Erb Street West, Waterloo ON N2T 2K8, Can...
# 41    [200 Highland Rd, Kitchener ON N2M 1Y9, Canada]
# 42  [305 King St. W. Unit 102 (Water St N), Kitche...
# 43  [100 Arnold St (Lancaster), Kitchener ON N2H 6...
# 44                      [Waterloo ON N2J 4G8, Canada]
# 45                                           [Canada]
# 46  [550 Highland Rd W, Kitchener ON N2M 5G3, Canada]
# 47  [300 King St. W. (at Water St.), Kitchener ON,...
# 48                             [Kitchener ON, Canada]
# 49  [23 Eby St. S. (at Charles St. E.), Kitchener ...
#
#                    crossStreet                        id
# 0                at Phillip St  4e2df16952b111a1e374f9a3
# 1                          NaN  579e766ccd102f2ed7a0e778
# 2       Father David Bauer Dr.  4b631946f964a520d6622ae3
# 3         btw Erb & Willis Way  4b6c71ebf964a520ad3a2ce3
# 4                      Erb St.  4b549552f964a52020c127e3
# 5          at University Ave W  4b96bb77f964a520ebe034e3
# 6                        Weber  5356d10c11d2bbfbf6721509
# 7                          NaN  518fa5aa498e31f5de9f327c
# 8                          NaN  5b5a4928a5a315002ca35ec8
# 9               at Phillip St.  4b200a97f964a5207b2c24e3
# 10                         NaN  594088a51cf2e108a4c6b31f
# 11               at Charles St  4b003747f964a520953b22e3
# 12          at University Av W  596d304eb1538e4ee5bd324e
# 13                    Hazel St  4efb957a775bec1428c2b0f1
# 14            at Ontario St. N  4e5a534eb0fbdca30a092712
# 15                         NaN  4d92640d7ac3a35da21ec025
# 16  Fred Nichols Campus Centre  4b731aeff964a520bd9b2de3
# 17                         NaN  4b64f349f964a520d9db2ae3
# 18                         NaN  4fae50e1e4b08260e3d62ee5
# 19               at Regina St.  4b06fbbcf964a520c4f422e3
# 20             at Davenport Rd  4bc0ea4b4cdfc9b658c39321
# 21       btw Claremont & Union  4bc08ace74a9a593d227d0f6
# 22                         NaN  4b926b41f964a5201ff833e3
# 23                         NaN  506f45cfe4b06a509e17fd75
# 24                         NaN  4b61c111f964a520a8202ae3
# 25             Spadina/baldwin  4ba00638f964a5204a5337e3
# 26                         NaN  4b40e6c6f964a52016bd25e3
# 27               at Phillip St  4b954346f964a520c89834e3
# 28       at Farmers Market Rd.  4c83982747cc224b164f909f
# 29                         NaN  591491768173cb55bcb732e8
# 30     Hickory St W / Larch St  56fdb3d1498e1b7c0cc1d093
# 31                         NaN  4f6227bfe4b073ddcaba2117
# 32                         NaN  5737577dcd102f038dddbed4
# 33             King&University  543dd411498eef542d382b70
# 34                         NaN  4bf48d8b706e20a16289a998
# 35                         NaN  5cd48cccb37e2b00398969fe
# 36               Lawrence Ave.  4b5e25e8f964a520538029e3
# 37                      Chopin  4ecd79fce5faa5ecff7a980c
# 38             at Westmount Dr  4e165d6ffa76a474496b805d
# 39                         NaN  4f1ba4ace4b0a627194f9910
# 40                         NaN  5ad7fd50356b4901d9a54545
# 41                         NaN  4d548f65b4deb1f748e9fa79
# 42                  Water St N  542ae263498e51a58dc43bff
# 43                   Lancaster  4e580d75b0fb4c4d61f9f3fe
# 44                         NaN  5dd97001c515cc000877405e
# 45                         NaN  4ba8f3c2f964a5203cfd39e3
# 46                         NaN  56d5661d498e043564c4bfa7
# 47                at Water St.  4c61584f13791b8d1ca651af
# 48                         NaN  4f6e6f43e4b0d638a2060cca
# 49           at Charles St. E.  4c1ce41ab4e62d7fbab8db93

# %%
#All Near Kitchener
# keep only columns that include venue name, and anything that is associated with location
filtered_columns4 = ['name', 'categories'] + [col for col in df8.columns if col.startswith('location.')] + ['id']
df8_filtered = df8.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type4(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df8_filtered['categories'] = df8_filtered.apply(get_category_type4, axis=1)

# clean column names by keeping only last term
df8_filtered.columns = [column.split('.')[-1] for column in df8_filtered.columns]

df8_filtered
# Out:
#                                                  name  \
# 0                             Modern India Restaurant
# 1                              Bombay Bhel Restaurant
# 2                          Genesis Spanish Restaurant
# 3                         Cambridge Family Restaurant
# 4                                Cambridge Restaurant
# 5                                    Eagle Restaurant
# 6                                 Shanghai Restaurant
# 7   HomeTaste - Indian Restaurant, Catering and Ti...
# 8                                Martini's restaurant
# 9                              126 Chinese Restaurant
# 10                                       Ben Thanh 邊城
# 11                       Hong Kong Seafood Restaurant
# 12                                           Milton's
# 13                               Fifty's Grill & Deli
#
#                  categories                address        lat        lng  \
# 0         Indian Restaurant         4355 King St E  43.406960 -80.396880
# 1         Indian Restaurant  4336 King Street East  43.407860 -80.396372
# 2        Spanish Restaurant                    NaN  43.398587 -80.363134
# 3                Restaurant      752 King st, East  43.395407 -80.357521
# 4                      None        752 king street  43.395376 -80.357562
# 5         Food & Drink Shop   1390 Eagle Street N.  43.404948 -80.347585
# 6                      None            King Street  43.395262 -80.357426
# 7   North Indian Restaurant     1601 River Rd East  43.428770 -80.422145
# 8       American Restaurant      2980 king st east  43.428779 -80.432767
# 9                Restaurant         2922 King St E  43.429418 -80.435049
# 10    Vietnamese Restaurant     500 Fairway Rd. S.  43.421054 -80.446581
# 11                     None     700 Strasburg Road  43.404208 -80.472301
# 12      American Restaurant        2979 King St. E  43.428672 -80.433417
# 13                    Diner        426 Hespeler Rd  43.395530 -80.324595
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.40696016679312...      2049    N2P 2E9
# 1   [{'label': 'display', 'lat': 43.40786, 'lng': ...      2157    N2P 3W6
# 2   [{'label': 'display', 'lat': 43.398587, 'lng':...      3545        NaN
# 3   [{'label': 'display', 'lat': 43.395407, 'lng':...      3909     N3h3n9
# 4   [{'label': 'display', 'lat': 43.395376, 'lng':...      3905        NaN
# 5   [{'label': 'display', 'lat': 43.40494822033108...      4962        NaN
# 6   [{'label': 'display', 'lat': 43.395262, 'lng':...      3914        NaN
# 7   [{'label': 'display', 'lat': 43.42876975908951...      4575    N2A 3Y4
# 8   [{'label': 'display', 'lat': 43.42877888348605...      4902    N2A 1A9
# 9   [{'label': 'display', 'lat': 43.429418, 'lng':...      5051    N2A 1A7
# 10  [{'label': 'display', 'lat': 43.42105395284015...      4847    N2C 1X3
# 11  [{'label': 'display', 'lat': 43.40420847077937...      5668        NaN
# 12  [{'label': 'display', 'lat': 43.42867182719811...      4916        N2A
# 13  [{'label': 'display', 'lat': 43.39553017978626...      6551    N1R 6J7
#
#     cc       city state country  \
# 0   CA  Kitchener    ON  Canada
# 1   CA  Kitchener    ON  Canada
# 2   CA        NaN   NaN  Canada
# 3   CA  Cambridge    ON  Canada
# 4   CA  Cambridge    ON  Canada
# 5   CA  Cambridge    ON  Canada
# 6   CA  Cambridge    ON  Canada
# 7   CA  Kitchener    ON  Canada
# 8   CA  Kitchener    ON  Canada
# 9   CA  Kitchener    ON  Canada
# 10  CA  Kitchener    ON  Canada
# 11  CA  Kitchener    ON  Canada
# 12  CA  Kitchener    ON  Canada
# 13  CA  Cambridge    ON  Canada
#
#                                      formattedAddress        crossStreet  \
# 0   [4355 King St E (at Sportsworld Dr), Kitchener...  at Sportsworld Dr
# 1   [4336 King Street East (Hellmann Road), Kitche...      Hellmann Road
# 2                                            [Canada]                NaN
# 3    [752 King st, East, Cambridge ON N3h3n9, Canada]                NaN
# 4             [752 king street, Cambridge ON, Canada]                NaN
# 5   [1390 Eagle Street N. (Concession), Cambridge ...         Concession
# 6         [King Street (Chuch), Cambridge ON, Canada]              Chuch
# 7   [1601 River Rd East, Kitchener ON N2A 3Y4, Can...                NaN
# 8   [2980 king st east, Kitchener ON N2A 1A9, Canada]                NaN
# 9   [2922 King St E (King & Morgan), Kitchener ON ...      King & Morgan
# 10  [500 Fairway Rd. S. (at Wilson Ave.), Kitchene...     at Wilson Ave.
# 11         [700 Strasburg Road, Kitchener ON, Canada]                NaN
# 12        [2979 King St. E, Kitchener ON N2A, Canada]                NaN
# 13  [426 Hespeler Rd (at Bishop St), Cambridge ON ...       at Bishop St
#
#                           id
# 0   4bcccd148920b713d9c59edc
# 1   56c2632dcd108bebe43a5dd4
# 2   57c74fea498e24c106a0bc6f
# 3   4c4b0122c668e21e9f4274f9
# 4   4cbb24c19552b60cc838de8b
# 5   4d0f3e5271e8a1cd749679bd
# 6   4b7c7470f964a52088942fe3
# 7   5fe03385e80f01698ae8fe9d
# 8   4c0aee3732daef3bb3bc4b50
# 9   5674975f498e98ce88afe43e
# 10  4b44ccaef964a52087fc25e3
# 11  4e6ba31445ddadf2d0fe5de6
# 12  4b624c17f964a520f2402ae3
# 13  4b704062f964a5201a0e2de3

# %%
#Waterloo Determining Average number or restauraunts in neighbourhood
Number_of_Waterloo_Sushi_Venues = len(df4.index)
Number_of_Waterloo_All_Venues = len(df5.index)

def averagewaerloo (Number_of_Waterloo_Sushi_Venues,Number_of_Waterloo_All_Venues):
    return (Number_of_Waterloo_Sushi_Venues + Number_of_Waterloo_All_Venues)/2
avgw = averagewaerloo(int(Number_of_Waterloo_Sushi_Venues),int(Number_of_Waterloo_All_Venues))


#Waterloo
print('Total number of restaurants Waterloo:', len(df5))
print('Total number of Waterloo sushi restaurants:', len(df4))
print('Percentage of sushi restaurants Waterloo: {:.2f}%'.format(len(df4) / len(df5) * 100))
print('Average number of restaurants in Waterloo neighborhood', avgw)
# Out:
# Total number of restaurants Waterloo: 50
# Total number of Waterloo sushi restaurants: 24
# Percentage of sushi restaurants Waterloo: 48.00%
# Average number of restaurants in Waterloo neighborhood 37.0

# %%
#Kitchener Determining Average number or restauraunts in neighbourhood
Number_of_Kitchener_Sushi_Venues = len(df7.index)
Number_of_Kitchener_All_Venues = len(df8.index)

def averagekitchener (Number_of_Kitchener_Sushi_Venues,Number_of_Kitchener_All_Venues):
    return (Number_of_Kitchener_Sushi_Venues + Number_of_Kitchener_All_Venues)/2
avgk = averagekitchener(int(Number_of_Kitchener_Sushi_Venues),int(Number_of_Kitchener_All_Venues))


#Kitcener
print('Total number of restaurants Kitchener:', len(df8))
print('Total number of Kitchener sushi restaurants:', len(df7))
print('Percentage of sushi restaurants Kitchener: {:.2f}%'.format(len(df7) / len(df8) * 100))
print('Average number of restaurants in Kitchener neighborhood', avgk)
# Out:
# Total number of restaurants Kitchener: 14
# Total number of Kitchener sushi restaurants: 5
# Percentage of sushi restaurants Kitchener: 35.71%
# Average number of restaurants in Kitchener neighborhood 9.5

# %% [markdown]
# We'll view all the collected restaurants in our area of interest on a map, and also show sushi restaurants in different color.

# %%
#Combining Information on Shushi Restauraunts in the areas of Kitchener and Waterloo 
kw_map = folium.Map(location=[lat,lon], zoom_start=12) # generate map centred around Kitchener/ Waterloo area

folium.Marker(Waterloo, popup='Waterloo - University of Waterloo').add_to(kw_map)
folium.Marker(Kitchener, popup='Kitchener - Conestoga College').add_to(kw_map)

# add the Waterloo sushi restaurants as Purple and Blue circle markers
for lat, lng, label in zip(df4_filtered.lat, df4_filtered.lng, df4_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='Purple',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(kw_map)

# add the Kitchener sushi restaurants as Red and Blue circle markers
for lat, lng, label in zip(df7_filtered.lat, df7_filtered.lng, df7_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(kw_map)
    
# add all the Waterloo restaurants as Orange and Black circle markers
for lat, lng, label in zip(df5_filtered.lat, df5_filtered.lng, df5_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(kw_map)
    
# add the Kitchener restaurants as Green and Black circle markers
for lat, lng, label in zip(df8_filtered.lat, df8_filtered.lng, df8_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(kw_map)

# display map
kw_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3218d27953644c08be313786c7c98572%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3218d27953644c08be313786c7c98572%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3218d27953644c08be313786c7c98572%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3218d27953644c08be313786c7c98572%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.39553017978626%2C%20-80.57500457338743%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Now we have all the restaurants in area within few kilometers our respecive Universities/Colleges, and we know which ones are sushi restaurants! We also know which restaurants are in vicinity of Kitchener/ Waterloo area.
#
# This concludes the data gathering phase - we're now ready to use this data for analysis to produce the report on optimal locations for a new sushi restaurant!
